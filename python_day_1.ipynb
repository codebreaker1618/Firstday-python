# %% [markdown]
# hi i am writing python code

# %% [markdown]
# 1. integer

# %%
population = 97429759275
print(population)
# Out:
# 97429759275

# %%
years_until_2030 = 2030 - 2025
print(years_until_2030)
# Out:
# 5

# %%
type(years_until_2030)
# Out:
# int

# %% [markdown]
# 2. FLOAT

# %%
INFLATION_RATE = 5.42
GDP_RATE = 6.3
print("the inflation rate today is =" , INFLATION_RATE)
# Out:
# the inflation rate today is = 5.42

# %% [markdown]
# 3. STRING

# %%
name = "shauna"
print(name)
print("her name is " , name)
# Out:
# shauna
# her name is  shauna

# %% [markdown]
# 4. list- list of values seperated with a comma

# %%
abc =["pizza" ,"burger" ,"pasta"]
print(abc)
# Out:
# ['pizza', 'burger', 'pasta']

# %%
type(abc)
# Out:
# list

# %% [markdown]
# 5. how list solves problems

# %%
numbers = [ 346 , 420 , 123, 25 , 503 , 96]
print(numbers)
numbers.append(69)
print(numbers)
numbers.pop(2)
print(numbers)
# Out:
# [346, 420, 123, 25, 503, 96]
# [346, 420, 123, 25, 503, 96, 69]
# [346, 420, 25, 503, 96, 69]

# %%
print(sorted(numbers))
# Out:
# [25, 96, 123, 346, 420, 503]

# %% [markdown]
# 6. TUPLE

# %% [markdown]
# tuple is immutable- we cant chnage it, lists are mutable - we can change it

# %%
number =( 1, 6 ,"hi" , 3.7 )
print(number)
# Out:
# (1, 6, 'hi', 3.7)

# %%
type(number)
# Out:
# tuple
